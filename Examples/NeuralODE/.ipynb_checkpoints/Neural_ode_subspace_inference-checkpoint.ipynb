# %% [markdown]
# # Uncertainty Analysis of Neural ODE's using Subspace Inference Method
#
# This work uses [DiffEqFlux.jl](https://github.com/SciML/DiffEqFlux.jl) to create Neural ODE's.
#
# ### Use packages

# %%
using Flux, DiffEqFlux
using BSON: @save
using BSON: @load
using Zygote
using SubspaceInference
using DifferentialEquations
using PyPlot;
using Flux: Data.DataLoader;
# Out:
# ┌ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1278

# %% [markdown]
# ### generate a time series of an ODE

# %%
u0 = Float32[2.; 0.]
datasize = 30
tspan = (0.0f0,1.5f0)

function trueODEfunc(du,u,p,t)
    true_A = [-0.1 2.0; -2.0 -0.1]
    du .= ((u.^3)'true_A)'
end
t = range(tspan[1],tspan[2],length=datasize)
prob = ODEProblem(trueODEfunc,u0,tspan)
ode_data = Array(solve(prob,Tsit5(),saveat=t));
# Out:
# 2×30 Array{Float32,2}:
#  2.0  1.9465    1.74178  1.23837  0.577126  …  1.40688   1.37022   1.29214
#  0.0  0.798831  1.46473  1.80877  1.86465      0.451381  0.728698  0.972098

# %% [markdown]
# ### Create single layer Neural ODE

# %%
dudt = Chain(x -> x.^3,
             Dense(2,50,tanh),
             Dense(50,2))
n_ode = NeuralODE(dudt,tspan,Tsit5(),saveat=t,reltol=1e-7,abstol=1e-9)
ps = Flux.params(n_ode);

# %% [markdown]
# ### Plot ODE time series and prediction before training

# %%
pred = n_ode(u0) # Get the prediction using the correct initial condition
(fig, f_axes) = PyPlot.subplots(ncols=1, nrows=1)
f_axes.scatter(t,ode_data[1,:], c="red", marker=".", label = "data")
f_axes.scatter(t,pred[1,:], c="green", marker=".", label ="prediction")
f_axes.legend()
fig.show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### Pretrain Neural ODE

# %%
function predict_n_ode()
  n_ode(u0)
end
loss_n_ode() = sum(abs2,ode_data .- predict_n_ode())

data = Iterators.repeated((), 100)
opt = ADAM(0.1)
cb = function () #callback function to observe training
  display(loss_n_ode())
  # plot current prediction against data
  cur_pred = predict_n_ode()
end

# Display the ODE with the initial parameter values.
cb()

Flux.train!(loss_n_ode, ps, data, opt, cb = cb)

# %% [markdown]
# ### Generate Subspace Inference
#
# #### Define Cost Function

# %%
@load "n_ode_weights.bson" ps;
Flux.loadparams!(n_ode, ps);
L1(m, x, y) = sum(abs2, m(vec(x)) .- reshape(y,2,:)) #cost function;

# %% [markdown]
# #### Format Data

# %%
X = reshape(u0,:,1) #input
Y = reshape(ode_data,:,1) #output 

data =  DataLoader(X,Y, shuffle=true);

# %% [markdown]
# #### Generate Inference

# %%
chn, lp, W_swa, re = subspace_inference(n_ode, L1, data, opt,
  σ_z = 1.0,  σ_m = 1.0, σ_p = 1.0,
  itr =1000, T=100, c=1, M=20, print_freq=1)
# Out:
# type BinaryHeap has no field comparer
#
# Stacktrace:
#  [1] getproperty(::DataStructures.BinaryHeap{Float32,Base.Order.ForwardOrdering}, ::Symbol) at .\Base.jl:33
#  [2] #34 at C:\Users\manoos\.julia\packages\DiffEqCallbacks\b4ahb\src\iterative_and_periodic.jl:28 [inlined]
# ...

# %% [markdown]
# #### Plot Inference

# %%
ns = length(chn)
z = t
trajectories = Array{Float64}(undef,length(t),ns)
for i in 1:ns
  mn = re(chn[i])
  out = mn(u0)
  trajectories[:, i] = Array(out)[1,:]
end

mx = maximum(trajectories, dims=2)
mn = minimum(trajectories, dims=2)
val, loc = findmax(lp)
max_log = trajectories[:,loc]
(fig, f_axes) = PyPlot.subplots(ncols=1, nrows=1)
f_axes.scatter(z,ode_data[1,:], c="red", marker=".")
f_axes.plot(z,vec(mx), c="blue") #maximum values
f_axes.plot(z,vec(mn), c="green") #minimum values
f_axes.plot(z,vec(max_log), c="darkorange") #maximum log probability
f_axes.fill_between(z, vec(mx), vec(mn), alpha=0.5)
f_axes.set_title("Subspace: 50")
fig.show()
